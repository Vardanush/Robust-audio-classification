# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Combine graphs for robust accuracy under linf attacks
t1 = "baseline"
l1 = np.array([0.8666666666666667, 0.75, 0.6333333333333333, 0.5333333333333333, 0.44999999999999996, 0.4, 0.41666666666666663, 0.3666666666666667, 0.33333333333333337, 0.33333333333333337, 0.4666666666666667, 0.3833333333333333, 0.41666666666666663, 0.3833333333333333, 0.2833333333333333, 0.3666666666666667, 0.43333333333333335, 0.33333333333333337, 0.30000000000000004, 0.31666666666666665])
# No augmentation, label_smoothing_cross_entropy(e=0.1)
t2 = "label smoothing (epsilon=0.1)"
l2 = np.array([0.9166666666666666, 0.75, 0.6333333333333333, 0.55, 0.5166666666666666, 0.4833333333333333, 0.5333333333333333, 0.5166666666666666, 0.44999999999999996, 0.44999999999999996, 0.43333333333333335, 0.3833333333333333, 0.43333333333333335, 0.4, 0.3833333333333333, 0.44999999999999996, 0.4666666666666667, 0.35, 0.3666666666666667, 0.4])
# Random transformation, cross_entropy
t3 = "label smoothing (epsilon=0.1) + augmentation"
l3 = np.array([0.8666666666666667, 0.75, 0.7, 0.6166666666666667, 0.6666666666666667, 0.6166666666666667, 0.41666666666666663, 0.44999999999999996, 0.4, 0.33333333333333337, 0.35, 0.44999999999999996, 0.41666666666666663, 0.3833333333333333, 0.2833333333333333, 0.35, 0.44999999999999996, 0.33333333333333337, 0.3833333333333333, 0.30000000000000004])
title = np.transpose([t1, t2, t3])
result = np.transpose([l1, l2, l3])
import pandas as pd
df = pd.DataFrame(data=result, index=list(range(1, 21)), columns=title)
df = df.set_index(np.linspace(0,10,20))
df[['baseline', 'label smoothing (epsilon=0.1)', 'label smoothing (epsilon=0.1) + augmentation']].plot()
plt.title('Linf fast gradient attacks')
plt.legend(loc='upper right')
plt.xlabel('attack radius')
plt.ylabel('robust accuracy')
plt.show()

# %%
# Combine graphs for robust accuracy under linf attacks
t1 = "baseline"
l1 = np.array([0.85, 0.85, 0.8666666666666667, 0.8333333333333334, 0.8166666666666667, 0.8333333333333334, 0.8666666666666667, 0.8, 0.8, 0.7833333333333333, 0.7666666666666666, 0.7833333333333333, 0.75, 0.75, 0.8, 0.8, 0.75, 0.7, 0.7166666666666667, 0.75, 0.7166666666666667, 0.7666666666666666, 0.7166666666666667, 0.7, 0.6833333333333333, 0.7, 0.7, 0.75, 0.6833333333333333, 0.7166666666666667, 0.7, 0.6166666666666667, 0.75, 0.7, 0.6833333333333333, 0.6333333333333333, 0.7, 0.7, 0.6333333333333333, 0.6166666666666667, 0.6666666666666667, 0.7166666666666667, 0.6166666666666667, 0.6833333333333333, 0.65, 0.65, 0.6833333333333333, 0.55, 0.6666666666666667, 0.6166666666666667])
# No augmentation, label_smoothing_cross_entropy(e=0.1)
t2 = "label smoothing (epsilon=0.1)"
l2 = np.array([0.9166666666666666, 0.9166666666666666, 0.9, 0.9, 0.9, 0.8666666666666667, 0.8166666666666667, 0.8333333333333334, 0.85, 0.8166666666666667, 0.7833333333333333, 0.7833333333333333, 0.7333333333333334, 0.7, 0.7166666666666667, 0.7166666666666667, 0.6833333333333333, 0.75, 0.7, 0.7, 0.7333333333333334, 0.6666666666666667, 0.6833333333333333, 0.65, 0.6166666666666667, 0.65, 0.6666666666666667, 0.65, 0.6666666666666667, 0.7333333333333334, 0.6166666666666667, 0.6, 0.6166666666666667, 0.5666666666666667, 0.6333333333333333, 0.65, 0.55, 0.5833333333333333, 0.5833333333333333, 0.5833333333333333, 0.55, 0.6, 0.65, 0.5666666666666667, 0.55, 0.5666666666666667, 0.5333333333333333, 0.5833333333333333, 0.5666666666666667, 0.55])
# Random transformation, cross_entropy
t3 = "label smoothing (epsilon=0.1) + augmentation"
l3 = np.array([0.8666666666666667, 0.8166666666666667, 0.85, 0.8333333333333334, 0.8166666666666667, 0.7833333333333333, 0.75, 0.75, 0.75, 0.75, 0.7666666666666666, 0.75, 0.75, 0.7333333333333334, 0.75, 0.7333333333333334, 0.7, 0.7333333333333334, 0.7333333333333334, 0.7333333333333334, 0.75, 0.7333333333333334, 0.6833333333333333, 0.7333333333333334, 0.6833333333333333, 0.7166666666666667, 0.6833333333333333, 0.7166666666666667, 0.7166666666666667, 0.6833333333333333, 0.75, 0.7, 0.7166666666666667, 0.7, 0.6833333333333333, 0.6833333333333333, 0.65, 0.7, 0.65, 0.65, 0.65, 0.65, 0.6333333333333333, 0.7, 0.6666666666666667, 0.65, 0.6333333333333333, 0.6833333333333333, 0.6333333333333333, 0.6666666666666667])
title = np.transpose([t1, t2, t3])
result = np.transpose([l1, l2, l3])
import pandas as pd
df = pd.DataFrame(data=result, index=list(range(1, 51)), columns=title)
df = df.set_index(np.linspace(0,250,50))
df[['baseline', 'label smoothing (epsilon=0.1)', 'label smoothing (epsilon=0.1) + augmentation']].plot()
plt.title('L2 fast gradient attacks')
plt.legend(loc='upper right')
plt.xlabel('attack radius')
plt.ylabel('robust accuracy')
plt.show()
